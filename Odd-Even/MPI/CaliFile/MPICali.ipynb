# %% [markdown]
# # CUDA Thicket Plotting

# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
#Read in all the files

# %%
tk = th.Thicket.from_caliperreader(glob("/scratch/user/riley.szecsy/FinalProject/CUDA/CaliFile/*.cali"))

# %%
# Performance data
tk.dataframe
# Out:
#                                                                nid  \
# node                                              profile
# {'name': 'comm_small', 'type': 'function'}        32601293    <NA>
#                                                   1770082801     8
# {'name': 'comp_small', 'type': 'function'}        32601293    <NA>
#                                                   1770082801    10
# {'name': 'whole_computation', 'type': 'function'} 32601293       1
#                                                   1770082801     1
# {'name': 'comm', 'type': 'function'}              32601293       3
#                                                   1770082801     3
# {'name': 'comm_large', 'type': 'function'}        32601293       4
#                                                   1770082801     4
# {'name': 'comp', 'type': 'function'}              32601293       5
#                                                   1770082801     5
# {'name': 'comp_large', 'type': 'function'}        32601293       6
#                                                   1770082801     6
# {'name': 'data_init', 'type': 'function'}         32601293       2
#                                                   1770082801     2
#
#                                                                spot.channel  \
# node                                              profile
# {'name': 'comm_small', 'type': 'function'}        32601293             None
#                                                   1770082801  regionprofile
# {'name': 'comp_small', 'type': 'function'}        32601293             None
#                                                   1770082801  regionprofile
# {'name': 'whole_computation', 'type': 'function'} 32601293    regionprofile
#                                                   1770082801  regionprofile
# {'name': 'comm', 'type': 'function'}              32601293    regionprofile
#                                                   1770082801  regionprofile
# {'name': 'comm_large', 'type': 'function'}        32601293    regionprofile
#                                                   1770082801  regionprofile
# {'name': 'comp', 'type': 'function'}              32601293    regionprofile
#                                                   1770082801  regionprofile
# {'name': 'comp_large', 'type': 'function'}        32601293    regionprofile
#                                                   1770082801  regionprofile
# {'name': 'data_init', 'type': 'function'}         32601293    regionprofile
#                                                   1770082801  regionprofile
#
#                                                               Min time/rank  \
# node                                              profile
# {'name': 'comm_small', 'type': 'function'}        32601293              NaN
#                                                   1770082801       0.000019
# {'name': 'comp_small', 'type': 'function'}        32601293              NaN
#                                                   1770082801       0.000007
# {'name': 'whole_computation', 'type': 'function'} 32601293         0.315762
#                                                   1770082801       0.617673
# {'name': 'comm', 'type': 'function'}              32601293         0.000169
#                                                   1770082801       0.000307
# {'name': 'comm_large', 'type': 'function'}        32601293         0.000105
#                                                   1770082801       0.000199
# {'name': 'comp', 'type': 'function'}              32601293         0.000198
#                                                   1770082801       0.000370
# {'name': 'comp_large', 'type': 'function'}        32601293         0.000183
#                                                   1770082801       0.000337
# {'name': 'data_init', 'type': 'function'}         32601293         0.000015
#                                                   1770082801       0.000011
#
#                                                               Max time/rank  \
# node                                              profile
# {'name': 'comm_small', 'type': 'function'}        32601293              NaN
#                                                   1770082801       0.000019
# {'name': 'comp_small', 'type': 'function'}        32601293              NaN
#                                                   1770082801       0.000007
# {'name': 'whole_computation', 'type': 'function'} 32601293         0.315762
#                                                   1770082801       0.617673
# {'name': 'comm', 'type': 'function'}              32601293         0.000169
#                                                   1770082801       0.000307
# {'name': 'comm_large', 'type': 'function'}        32601293         0.000105
#                                                   1770082801       0.000199
# {'name': 'comp', 'type': 'function'}              32601293         0.000198
#                                                   1770082801       0.000370
# {'name': 'comp_large', 'type': 'function'}        32601293         0.000183
#                                                   1770082801       0.000337
# {'name': 'data_init', 'type': 'function'}         32601293         0.000015
#                                                   1770082801       0.000011
#
#                                                               Avg time/rank  \
# node                                              profile
# {'name': 'comm_small', 'type': 'function'}        32601293              NaN
#                                                   1770082801       0.000019
# {'name': 'comp_small', 'type': 'function'}        32601293              NaN
#                                                   1770082801       0.000007
# {'name': 'whole_computation', 'type': 'function'} 32601293         0.315762
#                                                   1770082801       0.617673
# {'name': 'comm', 'type': 'function'}              32601293         0.000169
#                                                   1770082801       0.000307
# {'name': 'comm_large', 'type': 'function'}        32601293         0.000105
#                                                   1770082801       0.000199
# {'name': 'comp', 'type': 'function'}              32601293         0.000198
#                                                   1770082801       0.000370
# {'name': 'comp_large', 'type': 'function'}        32601293         0.000183
#                                                   1770082801       0.000337
# {'name': 'data_init', 'type': 'function'}         32601293         0.000015
#                                                   1770082801       0.000011
#
#                                                               Total time  \
# node                                              profile
# {'name': 'comm_small', 'type': 'function'}        32601293           NaN
#                                                   1770082801    0.000019
# {'name': 'comp_small', 'type': 'function'}        32601293           NaN
#                                                   1770082801    0.000007
# {'name': 'whole_computation', 'type': 'function'} 32601293      0.315762
#                                                   1770082801    0.617673
# {'name': 'comm', 'type': 'function'}              32601293      0.000169
#                                                   1770082801    0.000307
# {'name': 'comm_large', 'type': 'function'}        32601293      0.000105
#                                                   1770082801    0.000199
# {'name': 'comp', 'type': 'function'}              32601293      0.000198
#                                                   1770082801    0.000370
# {'name': 'comp_large', 'type': 'function'}        32601293      0.000183
#                                                   1770082801    0.000337
# {'name': 'data_init', 'type': 'function'}         32601293      0.000015
#                                                   1770082801    0.000011
#
#                                                               Avg GPU time/rank  \
# node                                              profile
# {'name': 'comm_small', 'type': 'function'}        32601293                  NaN
#                                                   1770082801                NaN
# {'name': 'comp_small', 'type': 'function'}        32601293                  NaN
#                                                   1770082801                NaN
# {'name': 'whole_computation', 'type': 'function'} 32601293             0.000060
#                                                   1770082801           0.000073
# {'name': 'comm', 'type': 'function'}              32601293             0.000004
#                                                   1770082801           0.000006
# {'name': 'comm_large', 'type': 'function'}        32601293             0.000004
#                                                   1770082801           0.000006
# {'name': 'comp', 'type': 'function'}              32601293             0.000056
#                                                   1770082801           0.000068
# {'name': 'comp_large', 'type': 'function'}        32601293             0.000056
#                                                   1770082801           0.000068
# {'name': 'data_init', 'type': 'function'}         32601293                  NaN
#                                                   1770082801                NaN
#
#                                                               Min GPU time/rank  \
# node                                              profile
# {'name': 'comm_small', 'type': 'function'}        32601293                  NaN
#                                                   1770082801                NaN
# {'name': 'comp_small', 'type': 'function'}        32601293                  NaN
#                                                   1770082801                NaN
# {'name': 'whole_computation', 'type': 'function'} 32601293             0.000060
#                                                   1770082801           0.000073
# {'name': 'comm', 'type': 'function'}              32601293             0.000004
#                                                   1770082801           0.000006
# {'name': 'comm_large', 'type': 'function'}        32601293             0.000004
#                                                   1770082801           0.000006
# {'name': 'comp', 'type': 'function'}              32601293             0.000056
#                                                   1770082801           0.000068
# {'name': 'comp_large', 'type': 'function'}        32601293             0.000056
#                                                   1770082801           0.000068
# {'name': 'data_init', 'type': 'function'}         32601293                  NaN
#                                                   1770082801                NaN
#
#                                                               Max GPU time/rank  \
# node                                              profile
# {'name': 'comm_small', 'type': 'function'}        32601293                  NaN
#                                                   1770082801                NaN
# {'name': 'comp_small', 'type': 'function'}        32601293                  NaN
#                                                   1770082801                NaN
# {'name': 'whole_computation', 'type': 'function'} 32601293             0.000060
#                                                   1770082801           0.000073
# {'name': 'comm', 'type': 'function'}              32601293             0.000004
#                                                   1770082801           0.000006
# {'name': 'comm_large', 'type': 'function'}        32601293             0.000004
#                                                   1770082801           0.000006
# {'name': 'comp', 'type': 'function'}              32601293             0.000056
#                                                   1770082801           0.000068
# {'name': 'comp_large', 'type': 'function'}        32601293             0.000056
#                                                   1770082801           0.000068
# {'name': 'data_init', 'type': 'function'}         32601293                  NaN
#                                                   1770082801                NaN
#
#                                                               Total GPU time  \
# node                                              profile
# {'name': 'comm_small', 'type': 'function'}        32601293               NaN
#                                                   1770082801             NaN
# {'name': 'comp_small', 'type': 'function'}        32601293               NaN
#                                                   1770082801             NaN
# {'name': 'whole_computation', 'type': 'function'} 32601293          0.000060
#                                                   1770082801        0.000073
# {'name': 'comm', 'type': 'function'}              32601293          0.000004
#                                                   1770082801        0.000006
# {'name': 'comm_large', 'type': 'function'}        32601293          0.000004
#                                                   1770082801        0.000006
# {'name': 'comp', 'type': 'function'}              32601293          0.000056
#                                                   1770082801        0.000068
# {'name': 'comp_large', 'type': 'function'}        32601293          0.000056
#                                                   1770082801        0.000068
# {'name': 'data_init', 'type': 'function'}         32601293               NaN
#                                                   1770082801             NaN
#
#                                                                            name
# node                                              profile
# {'name': 'comm_small', 'type': 'function'}        32601293                 None
#                                                   1770082801         comm_small
# {'name': 'comp_small', 'type': 'function'}        32601293                 None
#                                                   1770082801         comp_small
# {'name': 'whole_computation', 'type': 'function'} 32601293    whole_computation
#                                                   1770082801  whole_computation
# {'name': 'comm', 'type': 'function'}              32601293                 comm
#                                                   1770082801               comm
# {'name': 'comm_large', 'type': 'function'}        32601293           comm_large
#                                                   1770082801         comm_large
# {'name': 'comp', 'type': 'function'}              32601293                 comp
#                                                   1770082801               comp
# {'name': 'comp_large', 'type': 'function'}        32601293           comp_large
#                                                   1770082801         comp_large
# {'name': 'data_init', 'type': 'function'}         32601293            data_init
#                                                   1770082801          data_init

# %% [markdown]
# Groupby matrix size argument, available in the metadata (tk.metadata) to organize our performance data into 3 groupings.

# %%
#Thicket Tree
tk.statsframe.dataframe["time"] = 1
print(tk.tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 comm_small
# 1.000 comp_small
# 1.000 whole_computation
# ├─ 1.000 comm
# │  └─ 1.000 comm_large
# ├─ 1.000 comp
# │  └─ 1.000 comp_large
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 32601293             2.11.0-dev
# 1770082801           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 32601293    min#inclusive#sum#time.duration,max#inclusive#...
# 1770082801  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 32601293                                              2
# 1770082801                                            2
#
#                        spot.options  spot.channels cali.channel  \
# profile
# 32601293    cuda.gputime,node.order  regionprofile         spot
# 1770082801  cuda.gputime,node.order  regionprofile         spot
#
#            spot:cuda.gputime spot:node.order     spot:output  launchdate  \
# profile
# 32601293                true            true  v12-t4-i1.cali  1699810257
# 1770082801              true            true  v12-t4-i0.cali  1700003062
#
#                                                     libraries  \
# profile
# 32601293    [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1770082801  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                               cmdline cluster                    Algorithm  \
# profile
# 32601293    [./cudaoddeven, 12, 4, 1]       g  Odd Even Transposition Sort
# 1770082801  [./cudaoddeven, 12, 4, 0]       g  Odd Even Transposition Sort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize InputType  \
# profile
# 32601293               CUDA      int               4         12    Random
# 1770082801             CUDA      int               4         12    Sorted
#
#             num_threads  num_blocks  group_num implementation_source
# profile
# 32601293              4           6          9                Online
# 1770082801            4           6          9                Online

# %%
gb = tk.groupby("InputType")
# Out:
# 2  thickets created...
# {'Random': <thicket.thicket.Thicket object at 0x2ad4dfad5df0>, 'Sorted': <thicket.thicket.Thicket object at 0x2ad4dfb5d8e0>}

# %% [markdown]
# Compose these 3 groups column-wise to get a holistic view of the data

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_threads"
)

# %%
ctk.dataframe
# Out:
#                                                               Random  \
#                                                                  nid
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4             <NA>
# {'name': 'comp_small', 'type': 'function'}        4             <NA>
# {'name': 'whole_computation', 'type': 'function'} 4                1
# {'name': 'comm', 'type': 'function'}              4                3
# {'name': 'comm_large', 'type': 'function'}        4                4
# {'name': 'comp', 'type': 'function'}              4                5
# {'name': 'comp_large', 'type': 'function'}        4                6
# {'name': 'data_init', 'type': 'function'}         4                2
#
#                                                                               \
#                                                                 spot.channel
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                     None
# {'name': 'comp_small', 'type': 'function'}        4                     None
# {'name': 'whole_computation', 'type': 'function'} 4            regionprofile
# {'name': 'comm', 'type': 'function'}              4            regionprofile
# {'name': 'comm_large', 'type': 'function'}        4            regionprofile
# {'name': 'comp', 'type': 'function'}              4            regionprofile
# {'name': 'comp_large', 'type': 'function'}        4            regionprofile
# {'name': 'data_init', 'type': 'function'}         4            regionprofile
#
#                                                                              \
#                                                               Min time/rank
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                     NaN
# {'name': 'comp_small', 'type': 'function'}        4                     NaN
# {'name': 'whole_computation', 'type': 'function'} 4                0.315762
# {'name': 'comm', 'type': 'function'}              4                0.000169
# {'name': 'comm_large', 'type': 'function'}        4                0.000105
# {'name': 'comp', 'type': 'function'}              4                0.000198
# {'name': 'comp_large', 'type': 'function'}        4                0.000183
# {'name': 'data_init', 'type': 'function'}         4                0.000015
#
#                                                                              \
#                                                               Max time/rank
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                     NaN
# {'name': 'comp_small', 'type': 'function'}        4                     NaN
# {'name': 'whole_computation', 'type': 'function'} 4                0.315762
# {'name': 'comm', 'type': 'function'}              4                0.000169
# {'name': 'comm_large', 'type': 'function'}        4                0.000105
# {'name': 'comp', 'type': 'function'}              4                0.000198
# {'name': 'comp_large', 'type': 'function'}        4                0.000183
# {'name': 'data_init', 'type': 'function'}         4                0.000015
#
#                                                                              \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                     NaN
# {'name': 'comp_small', 'type': 'function'}        4                     NaN
# {'name': 'whole_computation', 'type': 'function'} 4                0.315762
# {'name': 'comm', 'type': 'function'}              4                0.000169
# {'name': 'comm_large', 'type': 'function'}        4                0.000105
# {'name': 'comp', 'type': 'function'}              4                0.000198
# {'name': 'comp_large', 'type': 'function'}        4                0.000183
# {'name': 'data_init', 'type': 'function'}         4                0.000015
#
#                                                                           \
#                                                               Total time
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                  NaN
# {'name': 'comp_small', 'type': 'function'}        4                  NaN
# {'name': 'whole_computation', 'type': 'function'} 4             0.315762
# {'name': 'comm', 'type': 'function'}              4             0.000169
# {'name': 'comm_large', 'type': 'function'}        4             0.000105
# {'name': 'comp', 'type': 'function'}              4             0.000198
# {'name': 'comp_large', 'type': 'function'}        4             0.000183
# {'name': 'data_init', 'type': 'function'}         4             0.000015
#
#                                                                                  \
#                                                               Avg GPU time/rank
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                         NaN
# {'name': 'comp_small', 'type': 'function'}        4                         NaN
# {'name': 'whole_computation', 'type': 'function'} 4                    0.000060
# {'name': 'comm', 'type': 'function'}              4                    0.000004
# {'name': 'comm_large', 'type': 'function'}        4                    0.000004
# {'name': 'comp', 'type': 'function'}              4                    0.000056
# {'name': 'comp_large', 'type': 'function'}        4                    0.000056
# {'name': 'data_init', 'type': 'function'}         4                         NaN
#
#                                                                                  \
#                                                               Min GPU time/rank
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                         NaN
# {'name': 'comp_small', 'type': 'function'}        4                         NaN
# {'name': 'whole_computation', 'type': 'function'} 4                    0.000060
# {'name': 'comm', 'type': 'function'}              4                    0.000004
# {'name': 'comm_large', 'type': 'function'}        4                    0.000004
# {'name': 'comp', 'type': 'function'}              4                    0.000056
# {'name': 'comp_large', 'type': 'function'}        4                    0.000056
# {'name': 'data_init', 'type': 'function'}         4                         NaN
#
#                                                                                  \
#                                                               Max GPU time/rank
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                         NaN
# {'name': 'comp_small', 'type': 'function'}        4                         NaN
# {'name': 'whole_computation', 'type': 'function'} 4                    0.000060
# {'name': 'comm', 'type': 'function'}              4                    0.000004
# {'name': 'comm_large', 'type': 'function'}        4                    0.000004
# {'name': 'comp', 'type': 'function'}              4                    0.000056
# {'name': 'comp_large', 'type': 'function'}        4                    0.000056
# {'name': 'data_init', 'type': 'function'}         4                         NaN
#
#                                                                               \
#                                                               Total GPU time
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                      NaN
# {'name': 'comp_small', 'type': 'function'}        4                      NaN
# {'name': 'whole_computation', 'type': 'function'} 4                 0.000060
# {'name': 'comm', 'type': 'function'}              4                 0.000004
# {'name': 'comm_large', 'type': 'function'}        4                 0.000004
# {'name': 'comp', 'type': 'function'}              4                 0.000056
# {'name': 'comp_large', 'type': 'function'}        4                 0.000056
# {'name': 'data_init', 'type': 'function'}         4                      NaN
#
#                                                               Sorted  \
#                                                                  nid
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                8
# {'name': 'comp_small', 'type': 'function'}        4               10
# {'name': 'whole_computation', 'type': 'function'} 4                1
# {'name': 'comm', 'type': 'function'}              4                3
# {'name': 'comm_large', 'type': 'function'}        4                4
# {'name': 'comp', 'type': 'function'}              4                5
# {'name': 'comp_large', 'type': 'function'}        4                6
# {'name': 'data_init', 'type': 'function'}         4                2
#
#                                                                               \
#                                                                 spot.channel
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4            regionprofile
# {'name': 'comp_small', 'type': 'function'}        4            regionprofile
# {'name': 'whole_computation', 'type': 'function'} 4            regionprofile
# {'name': 'comm', 'type': 'function'}              4            regionprofile
# {'name': 'comm_large', 'type': 'function'}        4            regionprofile
# {'name': 'comp', 'type': 'function'}              4            regionprofile
# {'name': 'comp_large', 'type': 'function'}        4            regionprofile
# {'name': 'data_init', 'type': 'function'}         4            regionprofile
#
#                                                                              \
#                                                               Min time/rank
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                0.000019
# {'name': 'comp_small', 'type': 'function'}        4                0.000007
# {'name': 'whole_computation', 'type': 'function'} 4                0.617673
# {'name': 'comm', 'type': 'function'}              4                0.000307
# {'name': 'comm_large', 'type': 'function'}        4                0.000199
# {'name': 'comp', 'type': 'function'}              4                0.000370
# {'name': 'comp_large', 'type': 'function'}        4                0.000337
# {'name': 'data_init', 'type': 'function'}         4                0.000011
#
#                                                                              \
#                                                               Max time/rank
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                0.000019
# {'name': 'comp_small', 'type': 'function'}        4                0.000007
# {'name': 'whole_computation', 'type': 'function'} 4                0.617673
# {'name': 'comm', 'type': 'function'}              4                0.000307
# {'name': 'comm_large', 'type': 'function'}        4                0.000199
# {'name': 'comp', 'type': 'function'}              4                0.000370
# {'name': 'comp_large', 'type': 'function'}        4                0.000337
# {'name': 'data_init', 'type': 'function'}         4                0.000011
#
#                                                                              \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                0.000019
# {'name': 'comp_small', 'type': 'function'}        4                0.000007
# {'name': 'whole_computation', 'type': 'function'} 4                0.617673
# {'name': 'comm', 'type': 'function'}              4                0.000307
# {'name': 'comm_large', 'type': 'function'}        4                0.000199
# {'name': 'comp', 'type': 'function'}              4                0.000370
# {'name': 'comp_large', 'type': 'function'}        4                0.000337
# {'name': 'data_init', 'type': 'function'}         4                0.000011
#
#                                                                           \
#                                                               Total time
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4             0.000019
# {'name': 'comp_small', 'type': 'function'}        4             0.000007
# {'name': 'whole_computation', 'type': 'function'} 4             0.617673
# {'name': 'comm', 'type': 'function'}              4             0.000307
# {'name': 'comm_large', 'type': 'function'}        4             0.000199
# {'name': 'comp', 'type': 'function'}              4             0.000370
# {'name': 'comp_large', 'type': 'function'}        4             0.000337
# {'name': 'data_init', 'type': 'function'}         4             0.000011
#
#                                                                                  \
#                                                               Avg GPU time/rank
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                         NaN
# {'name': 'comp_small', 'type': 'function'}        4                         NaN
# {'name': 'whole_computation', 'type': 'function'} 4                    0.000073
# {'name': 'comm', 'type': 'function'}              4                    0.000006
# {'name': 'comm_large', 'type': 'function'}        4                    0.000006
# {'name': 'comp', 'type': 'function'}              4                    0.000068
# {'name': 'comp_large', 'type': 'function'}        4                    0.000068
# {'name': 'data_init', 'type': 'function'}         4                         NaN
#
#                                                                                  \
#                                                               Min GPU time/rank
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                         NaN
# {'name': 'comp_small', 'type': 'function'}        4                         NaN
# {'name': 'whole_computation', 'type': 'function'} 4                    0.000073
# {'name': 'comm', 'type': 'function'}              4                    0.000006
# {'name': 'comm_large', 'type': 'function'}        4                    0.000006
# {'name': 'comp', 'type': 'function'}              4                    0.000068
# {'name': 'comp_large', 'type': 'function'}        4                    0.000068
# {'name': 'data_init', 'type': 'function'}         4                         NaN
#
#                                                                                  \
#                                                               Max GPU time/rank
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                         NaN
# {'name': 'comp_small', 'type': 'function'}        4                         NaN
# {'name': 'whole_computation', 'type': 'function'} 4                    0.000073
# {'name': 'comm', 'type': 'function'}              4                    0.000006
# {'name': 'comm_large', 'type': 'function'}        4                    0.000006
# {'name': 'comp', 'type': 'function'}              4                    0.000068
# {'name': 'comp_large', 'type': 'function'}        4                    0.000068
# {'name': 'data_init', 'type': 'function'}         4                         NaN
#
#                                                                               \
#                                                               Total GPU time
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                      NaN
# {'name': 'comp_small', 'type': 'function'}        4                      NaN
# {'name': 'whole_computation', 'type': 'function'} 4                 0.000073
# {'name': 'comm', 'type': 'function'}              4                 0.000006
# {'name': 'comm_large', 'type': 'function'}        4                 0.000006
# {'name': 'comp', 'type': 'function'}              4                 0.000068
# {'name': 'comp_large', 'type': 'function'}        4                 0.000068
# {'name': 'data_init', 'type': 'function'}         4                      NaN
#
#                                                                             name
#
# node                                              num_threads
# {'name': 'comm_small', 'type': 'function'}        4                   comm_small
# {'name': 'comp_small', 'type': 'function'}        4                   comp_small
# {'name': 'whole_computation', 'type': 'function'} 4            whole_computation
# {'name': 'comm', 'type': 'function'}              4                         comm
# {'name': 'comm_large', 'type': 'function'}        4                   comm_large
# {'name': 'comp', 'type': 'function'}              4                         comp
# {'name': 'comp_large', 'type': 'function'}        4                   comp_large
# {'name': 'data_init', 'type': 'function'}         4                    data_init

# %% [markdown]
# Perform pandas operations to get the table in a desirable format for plotting

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), (128, "nid"), (1024, "nid"), (4096, "nid")], axis=1)
# Rename index to remove tuple
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])
# Drop "time" label as it is redundant
#ctk.dataframe.columns = ctk.dataframe.columns.droplevel(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 128
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#
# KeyError: 128
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-130d9e31e6cd> in <module>
#       1 # Drop unwanted columns
# ----> 2 ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), (128, "nid"), (1024, "nid"), (4096, "nid")], axis=1)
#       3 # Rename index to remove tuple
#       4 ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])
#       5 # Drop "time" label as it is redundant
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4589                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4590             else:
# -> 4591                 new_axis = axis.drop(labels, errors=errors)
#    4592             indexer = axis.get_indexer(new_axis)
#    4593
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/indexes/multi.py in drop(self, codes, level, errors)
#    2194         for level_codes in codes:
#    2195             try:
# -> 2196                 loc = self.get_loc(level_codes)
#    2197                 # get_loc returns either an integer, a slice, or a boolean
#    2198                 # mask
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/indexes/multi.py in get_loc(self, key)
#    2823             #  i.e. do we need _index_as_unique on that level?
#    2824             try:
# -> 2825                 return self._engine.get_loc(key)
#    2826             except TypeError:
#    2827                 # e.g. test_partial_slicing_with_multiindex partial string slicing
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# KeyError: (128, 'nid')

# %%
ctk.dataframe
# Out:
#                   Random                                             \
#                      nid   spot.channel Min time/rank Max time/rank
# name
# comm_small          <NA>           None           NaN           NaN
# comp_small          <NA>           None           NaN           NaN
# whole_computation      1  regionprofile      0.315762      0.315762
# comm                   3  regionprofile      0.000169      0.000169
# comm_large             4  regionprofile      0.000105      0.000105
# comp                   5  regionprofile      0.000198      0.000198
# comp_large             6  regionprofile      0.000183      0.000183
# data_init              2  regionprofile      0.000015      0.000015
#
#                                                               \
#                   Avg time/rank Total time Avg GPU time/rank
# name
# comm_small                  NaN        NaN               NaN
# comp_small                  NaN        NaN               NaN
# whole_computation      0.315762   0.315762          0.000060
# comm                   0.000169   0.000169          0.000004
# comm_large             0.000105   0.000105          0.000004
# comp                   0.000198   0.000198          0.000056
# comp_large             0.000183   0.000183          0.000056
# data_init              0.000015   0.000015               NaN
#
#                                                                      Sorted  \
#                   Min GPU time/rank Max GPU time/rank Total GPU time    nid
# name
# comm_small                      NaN               NaN            NaN      8
# comp_small                      NaN               NaN            NaN     10
# whole_computation          0.000060          0.000060       0.000060      1
# comm                       0.000004          0.000004       0.000004      3
# comm_large                 0.000004          0.000004       0.000004      4
# comp                       0.000056          0.000056       0.000056      5
# comp_large                 0.000056          0.000056       0.000056      6
# data_init                       NaN               NaN            NaN      2
#
#                                                                             \
#                     spot.channel Min time/rank Max time/rank Avg time/rank
# name
# comm_small         regionprofile      0.000019      0.000019      0.000019
# comp_small         regionprofile      0.000007      0.000007      0.000007
# whole_computation  regionprofile      0.617673      0.617673      0.617673
# comm               regionprofile      0.000307      0.000307      0.000307
# comm_large         regionprofile      0.000199      0.000199      0.000199
# comp               regionprofile      0.000370      0.000370      0.000370
# comp_large         regionprofile      0.000337      0.000337      0.000337
# data_init          regionprofile      0.000011      0.000011      0.000011
#
#                                                                   \
#                   Total time Avg GPU time/rank Min GPU time/rank
# name
# comm_small          0.000019               NaN               NaN
# comp_small          0.000007               NaN               NaN
# whole_computation   0.617673          0.000073          0.000073
# comm                0.000307          0.000006          0.000006
# comm_large          0.000199          0.000006          0.000006
# comp                0.000370          0.000068          0.000068
# comp_large          0.000337          0.000068          0.000068
# data_init           0.000011               NaN               NaN
#
#
#                   Max GPU time/rank Total GPU time
# name
# comm_small                      NaN            NaN
# comp_small                      NaN            NaN
# whole_computation          0.000073       0.000073
# comm                       0.000006       0.000006
# comm_large                 0.000006       0.000006
# comp                       0.000068       0.000068
# comp_large                 0.000068       0.000068
# data_init                       NaN            NaN

# %%
# Define common variables
function_names = set(ctk.dataframe.index.get_level_values("name"))
threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
matrix_sizes = sorted(ctk.dataframe.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-434a401c25c7> in <module>
#       1 # Define common variables
#       2 function_names = set(ctk.dataframe.index.get_level_values("name"))
# ----> 3 threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
#       4 matrix_sizes = sorted(ctk.dataframe.columns.tolist())
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/indexes/base.py in _get_level_values(self, level)
#    1987         Index(['a', 'b', 'c'], dtype='object')
#    1988         """
# -> 1989         self._validate_index_level(level)
#    1990         return self
#    1991
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/indexes/base.py in _validate_index_level(self, level)
#    1908                 )
#    1909         elif level != self.name:
# -> 1910             raise KeyError(
#    1911                 f"Requested level ({level}) does not match index name ({self.name})"
#    1912             )
#
# KeyError: 'Requested level (num_threads) does not match index name (name)'

# %% [markdown]
# # Plotting

# %% [markdown]
# ### Option 1
# Use `pandas.DataFrame.plot` to automatically interface with matplotlib

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %% [markdown]
# ### Option 2
# Use `matplotlib.pyplot` directly for more fine-grained control. Specifically for our case we can change the x axis scaling from base 10 to base 2.

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(matrix_sizes)
    plt.grid(True)
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(threads)
    plt.show()
    return fig, ax

# %% [markdown]
# # Examples

# %% [markdown]
# ## time

# %%
ctk.dataframe.loc["main"]

# %%
for name in function_names:
    plot_pandas(
        df=ctk.dataframe.loc[name],
        title=name,
        xlabel="Threads",
        ylabel="Time (seconds)",
        loglog=True
    )

# %%
for name in function_names:
    plot_mpl(
        df=ctk.dataframe.loc[name],
        title=name,
        xlabel="Threads",
        ylabel="Time (seconds)",
    )

# %% [markdown]
# ## Speedup

# %%
speedup_df = ctk.dataframe.loc[(slice(None),1), :].reset_index().drop("threads", axis=1).set_index("name")/ctk.dataframe

for name in function_names:
    plot_pandas(
        df=speedup_df.loc[name],
        title=f"{name}: thread-1/thread-N",
        xlabel="Threads",
        ylabel="Speedup",
        loglog=False
    )
